# %% [markdown]
# ## Defense Stats
# Aggregate individual defense stats by game from the defense csv into player stats per year for each team. Meant to be run after the recieving notebook.

# %%
import requests
import pandas as pd
pd.options.mode.chained_assignment = None

# %%
#Get recieving df
defense = pd.read_csv('C:\\Users\\Louie\\Repositories\\Springboard\\Capstone 1 - NFL Matchup Predictions\\Data Wrangling\\Data\\defensive.csv')
defense.head()
# Out:
#    year     game_id team        name  sacks  tackles  forced_fumbles  \
# 0  2009  2009091000  TEN  C.Finnegan      0        9               0
# 1  2009  2009091000  TEN   S.Tulloch      0        8               0
# 2  2009  2009091000  TEN      C.Hope      0        7               0
# 3  2009  2009091000  TEN    N.Harper      0        4               0
# 4  2009  2009091000  TEN   M.Griffin      0        4               1
#
#    interceptions
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0

# %%
#Get player stats to write to
player_stats = pd.read_csv('C:\\Users\\Louie\\Repositories\\Springboard\\Capstone 1 - NFL Matchup Predictions\\Data Wrangling\\Data\\players.csv')
player_stats.head()
# Out:
#    year team  pass_to_run  completion_perc  pass_len  interceptions_turnover  \
# 0  2009  ARI         0.62             0.66     10.70                      18
# 1  2009  ATL         0.56             0.58     11.14                      17
# 2  2009  BAL         0.52             0.63     11.33                      13
# 3  2009  BUF         0.51             0.58     10.89                      19
# 4  2009  CAR         0.47             0.57     11.63                      20
#
#    pass_touchdowns  rush_touchdowns  running_back_avg  rec_max_touchdowns  \
# 0               28               15              4.51                  13
# 1               26               15              4.89                  11
# 2               21               22              5.27                   7
# 3               17                6              4.46                   7
# 4               16               18              5.13                   7
#
#    max_yards_per_catch  rec_yards_max  rec_spread
# ...

# %%
#Get total stats
d_agg = defense.groupby(['year','team','name']).sum().reset_index()
d_agg.head()
# Out:
#    year team         name      game_id  sacks  tackles  forced_fumbles  \
# 0  2009  ARI     A.Branch  20091987179      2       14               0
# 1  2009  ARI  A.Highsmith   8036416133      0        6               0
# 2  2009  ARI      A.Rolle  28127534405      0       59               0
# 3  2009  ARI     A.Wilson  30136625714      3       61               0
# 4  2009  ARI      B.Berry  16072843465      6        9               0
#
#    interceptions
# 0              0
# 1              0
# 2              4
# 3              5
# 4              0
